# %% [markdown]
# #Type String

# %%
# Type string
print('Halo')
# Out:
# Halo

# %%
print(Halo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(Halo)
#
# NameError: name 'Halo' is not defined

# %%
print('Halo, nama saya')
# Out:
# Halo, nama saya

# %%
# Type Numerik dibagi menjadi:
# 1) Integer(int)/Bil. bulat. cth: 1; 25; 165
# 2) Float (desimal), cth: 3.14; 0.75
# 3) Complex number: 3 + 4j

# %%
print('umur saya:')
print(25)
print('saya lahir tahun')
print(2000)
print('tinggi saya')
print(165)
print('berat saya')
print(70.5)
# Out:
# umur saya:
# 25
# saya lahir tahun
# 2000
# tinggi saya
# 165
# berat saya
# 70.5

# %%
# Type Boolean, dibagi menjadi:
# 1) True , False
# 2) Logic: AND, OR, NOT
# 3) Ekspresi logic: >; <; >=; <=

# %%
print('TAKUMI')

# Mengambil substring
# Step 1: Membuat variabel
s = 'TAKUMI'
len(s)

# Menampilkan karakter pertama
print(s[0])
print(s[-6])
len(s)

k = 'Taumatawhakatangihangakoauauotamateapokaiwhenuakitanatahu'
len(k)
# Out:
# TAKUMI
# T
# T
# 57

# %%
s = 'TAKUMI'
len(s)
# Out:
# 6
